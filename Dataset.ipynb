# %% [markdown]
# <a href="https://colab.research.google.com/github/muradmy00/Dataset_in_ML/blob/main/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('survey lung cancer.csv')

print(df.to_string())
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0        M   69        1               2        2              1                1         2         1         2                  2         2                    2                      2           2         YES
# 1        M   74        2               1        1              1                2         2         2         1                  1         1                    2                      2           2         YES
# 2        F   59        1               1        1              2                1         2         1         2                  1         2                    2                      1           2          NO
# ...

# %%
print(df.isnull().to_string())
# Out:
#      GENDER    AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# 0     False  False    False           False    False          False            False     False     False     False              False     False                False                  False       False        False
# 1     False  False    False           False    False          False            False     False     False     False              False     False                False                  False       False        False
# 2     False  False    False           False    False          False            False     False     False     False              False     False                False                  False       False        False
# ...

# %%
print(df.isnull().sum())
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
print("First few rows of the dataset:")
print(df.head().to_string())
# Out:
# First few rows of the dataset:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0      M   69        1               2        2              1                1         2         1         2                  2         2                    2                      2           2         YES
# 1      M   74        2               1        1              1                2         2         2         1                  1         1                    2                      2           2         YES
# 2      F   59        1               1        1              2                1         2         1         2                  1         2                    2                      1           2          NO
# ...

# %%
df_filled = df.fillna(0)
print("\nDataset after filling null values:")
print(df_filled.to_string())
# Out:
# Dataset after filling null values:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0        M   69        1               2        2              1                1         2         1         2                  2         2                    2                      2           2         YES
# 1        M   74        2               1        1              1                2         2         2         1                  1         1                    2                      2           2         YES
# 2        F   59        1               1        1              2                1         2         1         2                  1         2                    2                      1           2          NO
# ...

# %%
df_dropped = df.dropna()
print("\nDataset after dropping rows with null values:")
print(df_dropped.to_string())
# Out:
# Dataset after dropping rows with null values:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0        M   69        1               2        2              1                1         2         1         2                  2         2                    2                      2           2         YES
# 1        M   74        2               1        1              1                2         2         2         1                  1         1                    2                      2           2         YES
# 2        F   59        1               1        1              2                1         2         1         2                  1         2                    2                      1           2          NO
# ...

# %%
df_dropped_cols = df.dropna(axis=1)
print("\nDataset after dropping columns with null values:")
print(df_dropped_cols.to_string())
# Out:
# Dataset after dropping columns with null values:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0        M   69        1               2        2              1                1         2         1         2                  2         2                    2                      2           2         YES
# 1        M   74        2               1        1              1                2         2         2         1                  1         1                    2                      2           2         YES
# 2        F   59        1               1        1              2                1         2         1         2                  1         2                    2                      1           2          NO
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
# Example: Filling missing values (if any)
df.fillna(df.mean(), inplace=True)

# %%
print(df.describe().to_string())
# Out:
#            GENDER         AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING    COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# count  309.000000  309.000000  309.000000      309.000000  309.000000     309.000000       309.000000  309.000000  309.000000  309.000000         309.000000  309.000000           309.000000             309.000000  309.000000   309.000000
# mean     0.524272   62.673139    1.563107        1.569579    1.498382       1.501618         1.504854    1.673139    1.556634    1.556634           1.556634    1.579288             1.640777               1.469256    1.556634     0.873786
# std      0.500221    8.210301    0.496806        0.495938    0.500808       0.500808         0.500787    0.469827    0.497588    0.497588           0.497588    0.494474             0.480551               0.499863    0.497588     0.332629
# ...

# %%
df.plot.hist(figsize=(15, 8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.box(figsize=(15, 8))
# Out:
# <Axes: >

# %%
df.plot(kind='scatter', x='AGE', y='LUNG_CANCER', figsize=(15, 8))
# Out:
# <Axes: xlabel='AGE', ylabel='LUNG_CANCER'>

# %%
df.plot.bar(figsize=(20, 10))
# Out:
# <Axes: >

# %%
df.plot.pie(y='LUNG_CANCER', figsize=(15, 8))
# Out:
# <Axes: ylabel='LUNG_CANCER'>

# %%
df.plot.area(figsize=(15, 8))
# Out:
# <Axes: >

# %%
df.plot.line(figsize=(15, 8))
# Out:
# <Axes: >

# %%
df.plot.scatter(x='AGE', y='LUNG_CANCER', figsize=(15, 8))
# Out:
# <Axes: xlabel='AGE', ylabel='LUNG_CANCER'>

# %%
df.plot.hexbin(x='AGE', y='LUNG_CANCER', gridsize=20, figsize=(15, 8))
# Out:
# <Axes: xlabel='AGE', ylabel='LUNG_CANCER'>

# %%
df.plot.kde(x='AGE', y='LUNG_CANCER', figsize=(15, 8))
# Out:
# <Axes: ylabel='Density'>
